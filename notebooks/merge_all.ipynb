# %% [markdown]
# ## Merge toute les données intérim (variables des 4 piliers)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

external_data = Path('../data/external/')
processed_data = Path('../data/processed/')
raw_data = Path('../data/raw/')
interim_data = Path('../data/interim/')

# %%
# !ls -lh ../data/interim/
# Out:
# total 9,6M
# -rw-rw-r-- 1 outini outini 822K nov.  26 20:38 acces_point_phys_service_publique.csv
# -rw-rw-r-- 1 outini outini  23K nov.  22 22:54 data_merge_V2.ipynb
# -rw-rw-r-- 1 outini outini 4,0M nov.  22 22:54 data_scol_menage_demandeurEmplois.csv
# -rw-rw-r-- 1 outini outini  79K nov.  22 22:54 IFN_var_scol_menage_demandeEmplois.ipynb
# -rw-rw-r-- 1 outini outini 837K nov.  26 23:58 taux_couverture_mobile.csv
# -rw-rw-r-- 1 outini outini 825K nov.  25 18:26 taux_couverture_THD.csv
# -rw-rw-r-- 1 outini outini 833K nov.  25 18:26 taux_demandeurs_emploi.csv
# -rw-rw-r-- 1 outini outini 1,3M nov.  25 18:26 taux_pauvrete.csv
# -rw-rw-r-- 1 outini outini 999K nov.  25 18:26 variable_minimas_V2.csv

# %%
df1 = pd.read_csv(interim_data/'acces_point_phys_service_publique.csv')
df2 = pd.read_csv(interim_data/'data_scol_menage_demandeurEmplois.csv')
df3 = pd.read_csv(interim_data/'taux_couverture_mobile.csv')
df4 = pd.read_csv(interim_data/'taux_couverture_THD.csv')
df5 = pd.read_csv(interim_data/'taux_demandeurs_emploi.csv')
df6 = pd.read_csv(interim_data/'taux_pauvrete.csv')
df7 = pd.read_csv(interim_data/'variable_minimas_V2.csv')

communes = pd.read_csv(raw_data/'table_insee_libcom_dep.csv').drop(columns=['Unnamed: 0'])

# %%
for data in [df1, df2, df3, df4, df5, df6, df7]:
    data = communes.merge(data, how='left', on='CODE_INSEE')     # obtenir meme base de 3 index : (CODE_INSEE, LIBCOM, DEP)

# %%
communes.merge(df1, how='left', on='CODE_INSEE')
# Out:
#       CODE_INSEE                 LIBCOM_x DEP_x                 LIBCOM_y DEP_y  ACCES_SERVICE_PUBLIC
# 0          01001  L'Abergement-Clémenciat    01  L'Abergement-Clémenciat    01                     0
# 1          01002    L'Abergement-de-Varey    01    L'Abergement-de-Varey    01                     0
# 2          01004        Ambérieu-en-Bugey    01        Ambérieu-en-Bugey    01                     0
# 3          01005      Ambérieux-en-Dombes    01      Ambérieux-en-Dombes    01                     1
# 4          01006                  Ambléon    01                  Ambléon    01                     0
# ...          ...                      ...   ...                      ...   ...                   ...
# 35008      97613            M'Tsangamouji   976            M'Tsangamouji   976                     0
# 35009      97614                 Ouangani   976                 Ouangani   976                     0
# 35010      97615                 Pamandzi   976                 Pamandzi   976                     1
# 35011      97616                     Sada   976                     Sada   976                     1
# 35012      97617                 Tsingoni   976                 Tsingoni   976                     1
#
# [35013 rows x 6 columns]

# %%
df = df1.merge(df2, how='inner', on=['CODE_INSEE'])
df = df.merge(df3, how='inner', on=['CODE_INSEE'])
df = df.merge(df4, how='inner', on=['CODE_INSEE'])
df = df.merge(df5, how='inner', on=['CODE_INSEE'])
df = df.merge(df6, how='inner', on=['CODE_INSEE'])
df = df.merge(df7, how='inner', on=['CODE_INSEE'])

print(df.shape)
# Out:
# (36013, 26)

# %%
df
# Out:
